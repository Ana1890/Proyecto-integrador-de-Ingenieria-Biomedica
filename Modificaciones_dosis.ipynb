# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pydicom

# %%
ds = pydicom.read_file(str(input('Ingrese un archivo: ')))
ds
# 1) Copiar la ruta donde está ubicado nuestro archivo
# 2) Colocar una barra más y copiar el nombre del archivo con la extensión incluida ('.dcm')
# 3) Sólo presionar "enter"
# Out:
# Ingrese un archivo: D:\Users\user\Documents\Tesis Ana\Set de pacientes\PI\1\2-BRAQUITERAPIA\RD.1.3.6.1.4.1.2452.6.2250649552.1266952679.1890813843.1298216529.dcm
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 220
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: RT Dose Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.6.1.4.1.2452.6.2250649552.1266952679.1890813843.1298216529
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.250.1.59.3.0.3.5.3
# (0002, 0013) Implementation Version Name         SH: 'ETIAM_DCMTK_353'
# (0002, 0016) Source Application Entity Title     AE: 'OTP_SCU'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'DOSE']
# (0008, 0012) Instance Creation Date              DA: '20190214'
# (0008, 0013) Instance Creation Time              TM: '150141'
# (0008, 0016) SOP Class UID                       UI: RT Dose Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.6.1.4.1.2452.6.2250649552.1266952679.1890813843.1298216529
# (0008, 0020) Study Date                          DA: '20190214'
# (0008, 0023) Content Date                        DA: '20190214'
# (0008, 0030) Study Time                          TM: '134813.203000'
# (0008, 0033) Content Time                        TM: '150141'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'RTDOSE'
# (0008, 0070) Manufacturer                        LO: 'Nucletron'
# (0008, 0090) Referring Physician's Name          PN: 'DRA BRUN'
# (0008, 0201) Timezone Offset From UTC            SH: '-0300'
# (0008, 1010) Station Name                        SH: 'OTP_BRACHY'
# (0008, 1030) Study Description                   LO: 'RT^BRAQUI (Adulto)'
# (0008, 103e) Series Description                  LO: 'Dose for SESION 1'
# (0008, 1040) Institutional Department Name       LO: ''
# (0008, 1090) Manufacturer's Model Name           LO: 'Oncentra'
# (0010, 0010) Patient's Name                      PN: 'PACIENTE1'
# (0010, 0020) Patient ID                          LO: '1'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'F'
# (0018, 0050) Slice Thickness                     DS: "0.0"
# (0018, 1020) Software Versions                   LO: 'OTP V4.5.3.30'
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.2452.6.2328121007.1089629375.3466060444.1037357843
# (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.2452.6.1546964300.1161411409.2703332783.26614925
# (0020, 0010) Study ID                            SH: '1'
# (0020, 0011) Series Number                       IS: "1"
# (0020, 0012) Acquisition Number                  IS: "1"
# (0020, 0013) Instance Number                     IS: None
# (0020, 0032) Image Position (Patient)            DS: [-95.250000, -276.731000, -747.057000]
# (0020, 0037) Image Orientation (Patient)         DS: [1, 0, 0, 0, 1, 0]
# (0020, 0052) Frame of Reference UID              UI: 1.3.12.2.1107.5.1.4.78531.30000019021411553200000000639
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 4000) Image Comments                      LT: ''
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0008) Number of Frames                    IS: "103"
# (0028, 0009) Frame Increment Pointer             AT: (3004, 000c)
# (0028, 0010) Rows                                US: 94
# (0028, 0011) Columns                             US: 87
# (0028, 0030) Pixel Spacing                       DS: [1.000000, 1.000000]
# (0028, 0100) Bits Allocated                      US: 32
# (0028, 0101) Bits Stored                         US: 32
# (0028, 0102) High Bit                            US: 31
# (0028, 0103) Pixel Representation                US: 0
# (3004, 0002) Dose Units                          CS: 'GY'
# (3004, 0004) Dose Type                           CS: 'PHYSICAL'
# (3004, 0006) Dose Comment                        LO: ''
# (3004, 000a) Dose Summation Type                 CS: 'PLAN'
# (3004, 000c) Grid Frame Offset Vector            DS: Array of 103 elements
# (3004, 000e) Dose Grid Scaling                   DS: "1.303852e-08"
# (3004, 0010)  RT Dose ROI Sequence   70 item(s) ----
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "3.901923"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "1"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "1"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "7.05509"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "2"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "2"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "7.922877"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "3"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "3"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "7.069272"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "4"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "4"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "3.76812"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "5"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "5"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "8.667424"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "6"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "6"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "10.494815"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "7"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "7"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "7.092017"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "8"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "8"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "10.426135"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "9"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "9"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "5.706317"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "10"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "10"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "7.731077"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "11"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "11"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "2.959628"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "12"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "12"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "8.94393"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "13"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "13"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "8.195233"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "14"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "14"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "7.860807"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "15"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "15"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "4.186629"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "16"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "16"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "5.270792"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "17"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "17"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "5.55979"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "18"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "18"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "3.12318"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "19"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "19"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "3.948978"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "20"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "20"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "13.644624"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "21"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "21"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "2.972409"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "22"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "22"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "11.86005"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "23"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "23"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "8.494036"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "24"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "24"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "10.201016"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "25"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "25"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "6.975946"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "26"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "26"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "7.98827"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "27"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "27"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "8.528376"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "28"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "28"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "2.549944"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "29"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "29"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "3.501351"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "30"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "30"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "9.589753"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "31"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "31"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "8.963132"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "32"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "32"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "3.899357"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "33"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "33"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "6.264623"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "34"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "34"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "7.918995"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "35"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "35"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "6.722755"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "36"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "36"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "7.529745"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "37"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "37"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "5.573482"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "38"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "38"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "4.765249"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "39"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "39"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "8.90143"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "40"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "40"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "5.681617"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "41"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "41"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "3.389257"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "42"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "42"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "4.621528"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "43"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "43"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "3.748128"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "44"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "44"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "8.427886"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "45"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "45"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "9.426556"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "46"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "46"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "7.053926"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "47"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "47"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "33.68164"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "48"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "48"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "5.623212"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "49"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "49"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "6.081685"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "50"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "50"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "8.56452"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "51"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "51"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "10.010069"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "52"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "52"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "8.321557"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "53"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "53"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "6.811303"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "54"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "54"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "7.821172"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "55"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "55"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "7.366697"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "56"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "56"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "5.322986"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "57"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "57"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "2.800221"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "58"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "58"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "3.287169"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "59"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "59"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "12.671248"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "60"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "60"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "3.034288"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "61"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "61"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "4.290903"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "62"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "62"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "2.574016"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "63"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "63"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "8.934311"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "64"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "64"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "6.715373"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "65"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "65"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "4.394123"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "66"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "66"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "3.576906"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "67"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "67"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "13.938179"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "68"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "68"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "4.297953"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "69"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "69"
#    ---------
#    (3004, 0002) Dose Units                          CS: 'GY'
#    (3004, 0012) Dose Value                          DS: "8.615229"
#    (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
#    (3006, 0084) Referenced ROI Number               IS: "70"
#    (300b, 0010) Private Creator                     LO: 'NUCLETRON'
#    (300b, 1000) Private tag data                    IS: "2"
#    (300b, 1001) Private tag data                    IS: "70"
#    ---------
# (3004, 0014) Tissue Heterogeneity Correction     CS: 'WATER'
# (3005, 0010) Private Creator                     LO: 'MDS NORDION CALCULATION'
# (3005, 1016) Private tag data                    DS: [-759.55, -674.69]
# (3006, 0002) Structure Set Label                 SH: 'PlanDosePoints'
# (3006, 0004) Structure Set Name                  LO: 'PlanDosePoints'
# (3006, 0008) Structure Set Date                  DA: '20190214'
# (3006, 0009) Structure Set Time                  TM: '150141'
# (3006, 0020)  Structure Set ROI Sequence   70 item(s) ----
#    (3006, 0022) ROI Number                          IS: "1"
#    (3006, 0024) Referenced Frame of Reference UID   UI: 1.3.12.2.1107.5.1.4.78531.30000019021411553200000000639
#    (3006, 0026) ROI Name                            LO: '-'
#    (3006, 0036) ROI Generation Algorithm            CS: 'AUTOMATIC'
#    (3006, 0038) ROI Generation Description          LO: 'POINT_SET_Target'
#    ---------
#    (3006, 0022) ROI Number                          IS: "2"
#    (3006, 0024) Referenced Frame of Reference UID   UI: 1.3.12.2.1107.5.1.4.78531.30000019021411553200000000639
#    (3006, 0026) ROI Name                            LO: '-'
#    (3006, 0036) ROI Generation Algorithm            CS: 'AUTOMATIC'
#    (3006, 0038) ROI Generation Description          LO: 'POINT_SET_Target'
#    ---------
#    (3006, 0022) ROI Number                          IS: "3"
#    (3006, 0024) Referenced Frame of Reference UID   UI: 1.3.12.2.1107.5.1.4.78531.30000019021411553200000000639
#    (3006, 0026) ROI Name                            LO: '-'
#    (3006, 0036) ROI Generation Algorithm            CS: 'AUTOMATIC'
#    (3006, 0038) ROI Generation Description          LO: 'POINT_SET_Target'
#    ---------
#    (3006, 0022) ROI Number                          IS: "4"
#    (3006, 0024) Referenced Frame of Reference UID   UI: 1.3.12.2.1107.5.1.4.78531.30000019021411553200000000639
#    (3006, 0026) ROI Name                            LO: '-'
#    (3006, 0036) ROI Generation Algorithm            CS: 'AUTOMATIC'
#    (3006, 0038) ROI Generation Description          LO: 'POINT_SET_Target'
#    ---------
#    (3006, 0022) ROI Number                          IS: "5"
#    (3006, 0024) Referenced Frame of Reference UID   UI: 1.3.12.2.1107.5.1.4.78531.30000019021411553200000000639
#    (3006, 0026) ROI Name                            LO: '-'
#    (3006, 0036) ROI Generation Algorithm            CS: 'AUTOMATIC'
#    (3006, 0038) ROI Generation Description          LO: 'POINT_SET_Target'
#    ---------
#    (3006, 0022) ROI Number                          IS: "6"
#    (3006, 0024) Referenced Frame of Reference UID   UI: 1.3.12.2.1107.5.1.4.78531.30000019021411553200000000639
#    (3006, 0026) ROI Name                            LO: '-'
#    (3006, 0036) ROI Generation Algorithm            CS: 'AUTOMATIC'
#    (3006, 0038) ROI Generation Description          LO: 'POINT_SET_Target'
#    ---------
#    (3006, 0022) ROI Number                          IS: "7"
#    (3006, 0024) Referenced Frame of Reference UID   UI: 1.3.12.2.1107.5.1.4.78531.30000019021411553200000000639
#    (3006, 0026) ROI Name                            LO: '-'
#    (3006, 0036) ROI Generation Algorithm            CS: 'AUTOMATIC'
#    (3006, 0038) ROI Generation Description          LO: 'POINT_SET_Target'
#    ---------
#    (3006, 0022) ROI Number                          IS: "8"
#    (3006, 0024) Referenced Frame of Reference UID   UI: 1.3.12.2.1107.5.1.4.78531.30000019021411553200000000639
#    (3006, 0026) ROI Name                            LO: '-'
#    (3006, 0036) ROI Generation Algorithm            CS: 'AUTOMATIC'
#    (3006, 0038) ROI Generation Description          LO: 'POINT_SET_Target'
#    ---------
#    (3006, 0022) ROI Number                          IS: "9"
#    (3006, 0024) Referenced Frame of Reference UID   UI: 1.3.12.2.1107.5.1.4.78531.30000019021411553200000000639
#    (3006, 0026) ROI Name                            LO: '-'
#    (3006, 0036) ROI Generation Algorithm            CS: 'AUTOMATIC'
#    (3006, 0038) ROI Generation Description          LO: 'POINT_SET_Target'
#    ---------
#    (3006, 0022) ROI Number                          IS: "10"
#    (3006, 0024) Referenced Frame of Reference UID   UI: 1.3.12.2.1107.5.1.4.78531.30000019021411553200000000639
#    (3006, 0026) ROI Name                            LO: '-'
#    (3006, 0036) ROI Generation Algorithm            CS: 'AUTOMATIC'
#    (3006, 0038) ROI Generation Description          LO: 'POINT_SET_Target'
#    ---------
#    (3006, 0022) ROI Number                          IS: "11"
#    (3006, 0024) Referenced Frame of Reference UID   UI: 1.3.12.2.1107.5.1.4.78531.30000019021411553200000000639
#    (3006, 0026) ROI Name                            LO: '-'
#    (3006, 0036) ROI Generation Algorithm            CS: 'AUTOMATIC'
#    (3006, 0038) ROI Generation Description          LO: 'POINT_SET_Target'
#    ---------
#    (3006, 0022) ROI Number                          IS: "12"
#    (3006, 0024) Referenced Frame of Reference UID   UI: 1.3.12.2.1107.5.1.4.78531.30000019021411553200000000639
#    (3006, 0026) ROI Name                            LO: '-'
#    (3006, 0036) ROI Generation Algorithm            CS: 'AUTOMATIC'
#    (3006, 0038) ROI Generation Description          LO: 'POINT_SET_Target'
#    ---------
#    (3006, 0022) ROI Number                          IS: "13"
#    (3006, 0024) Referenced Frame of Reference UID   UI: 1.3.12.2.1107.5.1.4.78531.30000019021411553200000000639
#    (3006, 0026) ROI Name                            LO: '-'
#    (3006, 0036) ROI Generation Algorithm            CS: 'AUTOMATIC'
#    (3006, 0038) ROI Generation Description          LO: 'POINT_SET_Target'
#    ---------
#    (3006, 0022) ROI Number                          IS: "14"
#    (3006, 0024) Referenced Frame of Reference UID   UI: 1.3.12.2.1107.5.1.4.78531.30000019021411553200000000639
#    (3006, 0026) ROI Name                            LO: '-'
#    (3006, 0036) ROI Generation Algorithm            CS: 'AUTOMATIC'
#    (3006, 0038) ROI Generation Description          LO: 'POINT_SET_Target'
#    ---------
#    (3006, 0022) ROI Number                          IS: "15"
#    (3006, 0024) Referenced Frame of Reference UID   UI: 1.3.12.2.1107.5.1.4.78531.30000019021411553200000000639
#    (3006, 0026) ROI Name                            LO: '-'
#    (3006, 0036) ROI Generation Algorithm            CS: 'AUTOMATIC'
#    (3006, 0038) ROI Generation Description          LO: 'POINT_SET_Target'
#    ---------
#    (3006, 0022) ROI Number                          IS: "16"
#    (3006, 0024) Referenced Frame of Reference UID   UI: 1.3.12.2.1107.5.1.4.78531.30000019021411553200000000639
#    (3006, 0026) ROI Name                            LO: '-'
#    (3006, 0036) ROI Generation Algorithm            CS: 'AUTOMATIC'
#    (3006, 0038) ROI Generation Description          LO: 'POINT_SET_Target'
#    ---------
#    (3006, 0022) ROI Number                          IS: "17"
#    (3006, 0024) Referenced Frame of Reference UID   UI: 1.3.12.2.1107.5.1.4.78531.30000019021411553200000000639
#    (3006, 0026) ROI Name                            LO: '-'
#    (3006, 0036) ROI Generation Algorithm            CS: 'AUTOMATIC'
#    (3006, 0038) ROI Generation Description          LO: 'POINT_SET_Target'
#    ---------
#    (3006, 0022) ROI Number                          IS: "18"
#    (3006, 0024) Referenced Frame of Reference UID   UI: 1.3.12.2.1107.5.1.4.78531.30000019021411553200000000639
#    (3006, 0026) ROI Name                            LO: '-'
#    (3006, 0036) ROI Generation Algorithm            CS: 'AUTOMATIC'
#    (3006, 0038) ROI Generation Description          LO: 'POINT_SET_Target'
#    ---------
#    (3006, 0022) ROI Number                          IS: "19"
#    (3006, 0024) Referenced Frame of Reference UID   UI: 1.3.12.2.1107.5.1.4.78531.30000019021411553200000000639
#    (3006, 0026) ROI Name                            LO: '-'
#    (3006, 0036) ROI Generation Algorithm            CS: 'AUTOMATIC'
#    (3006, 0038) ROI Generation Description          LO: 'POINT_SET_Target'
#    ---------
#    (3006, 0022) ROI Number                          IS: "20"
#    (3006, 0024) Referenced Frame of Reference UID   UI: 1.3.12.2.1107.5.1.4.78531.30000019021411553200000000639
#    (3006, 0026) ROI Name                            LO: '-'
#    (3006, 0036) ROI Generation Algorithm            CS: 'AUTOMATIC'
#    (3006, 0038) ROI Generation Description          LO: 'POINT_SET_Target'
#    ---------
#    (3006, 0022) ROI Number                          IS: "21"
#    (3006, 0024) Referenced Frame of Reference UID   UI: 1.3.12.2.1107.5.1.4.78531.30000019021411553200000000639
#    (3006, 0026) ROI Name                            LO: '-'
#    (3006, 0036) ROI Generation Algorithm            CS: 'AUTOMATIC'
#    (3006, 0038) ROI Generation Description          LO: 'POINT_SET_Target'
#    ---------
#    (3006, 0022) ROI Number                          IS: "22"
#    (3006, 0024) Referenced Frame of Reference UID   UI: 1.3.12.2.1107.5.1.4.78531.30000019021411553200000000639
#    (3006, 0026) ROI Name                            LO: '-'
#    (3006, 0036) ROI Generation Algorithm            CS: 'AUTOMATIC'
#    (3006, 0038) ROI Generation Description          LO: 'POINT_SET_Target'
#    ---------
#    (3006, 0022) ROI Number                          IS: "23"
#    (3006, 0024) Referenced Frame of Reference UID   UI: 1.3.12.2.1107.5.1.4.78531.30000019021411553200000000639
#    (3006, 0026) ROI Name                            LO: '-'
#    (3006, 0036) ROI Generation Algorithm            CS: 'AUTOMATIC'
#    (3006, 0038) ROI Generation Description          LO: 'POINT_SET_Target'
#    ---------
#    (3006, 0022) ROI Number                          IS: "24"
#    (3006, 0024) Referenced Frame of Reference UID   UI: 1.3.12.2.1107.5.1.4.78531.30000019021411553200000000639
#    (3006, 0026) ROI Name                            LO: '-'
#    (3006, 0036) ROI Generation Algorithm            CS: 'AUTOMATIC'
#    (3006, 0038) ROI Generation Description          LO: 'POINT_SET_Target'
#    ---------
#    (3006, 0022) ROI Number                          IS: "25"
#    (3006, 0024) Referenced Frame of Reference UID   UI: 1.3.12.2.1107.5.1.4.78531.30000019021411553200000000639
#    (3006, 0026) ROI Name                            LO: '-'
#    (3006, 0036) ROI Generation Algorithm            CS: 'AUTOMATIC'
#    (3006, 0038) ROI Generation Description          LO: 'POINT_SET_Target'
#    ---------
#    (3006, 0022) ROI Number                          IS: "26"
# ...
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: "1"
#       (3006, 0050) Contour Data                        DS: [-60.964844, -212.487544, -686.487600]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: "35"
#    ---------
#    (3006, 002a) ROI Display Color                   IS: [0, 0, 255]
#    (3006, 0040)  Contour Sequence   1 item(s) ----
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: "1"
#       (3006, 0050) Contour Data                        DS: [-71.983790, -227.425262, -717.107408]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: "36"
#    ---------
#    (3006, 002a) ROI Display Color                   IS: [0, 0, 255]
#    (3006, 0040)  Contour Sequence   1 item(s) ----
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: "1"
#       (3006, 0050) Contour Data                        DS: [-72.036572, -234.859444, -698.325000]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: "37"
#    ---------
#    (3006, 002a) ROI Display Color                   IS: [0, 0, 255]
#    (3006, 0040)  Contour Sequence   1 item(s) ----
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: "1"
#       (3006, 0050) Contour Data                        DS: [-76.445172, -229.545678, -693.272591]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: "38"
#    ---------
#    (3006, 002a) ROI Display Color                   IS: [0, 0, 255]
#    (3006, 0040)  Contour Sequence   1 item(s) ----
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: "1"
#       (3006, 0050) Contour Data                        DS: [-69.964844, -241.714844, -684.171350]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: "39"
#    ---------
#    (3006, 002a) ROI Display Color                   IS: [0, 0, 255]
#    (3006, 0040)  Contour Sequence   1 item(s) ----
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: "1"
#       (3006, 0050) Contour Data                        DS: [-31.224161, -229.757103, -709.632828]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: "40"
#    ---------
#    (3006, 002a) ROI Display Color                   IS: [0, 0, 255]
#    (3006, 0040)  Contour Sequence   1 item(s) ----
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: "1"
#       (3006, 0050) Contour Data                        DS: [-69.964844, -214.133570, -686.584550]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: "41"
#    ---------
#    (3006, 002a) ROI Display Color                   IS: [0, 0, 255]
#    (3006, 0040)  Contour Sequence   1 item(s) ----
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: "1"
#       (3006, 0050) Contour Data                        DS: [-24.317754, -235.714844, -686.325000]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: "42"
#    ---------
#    (3006, 002a) ROI Display Color                   IS: [0, 0, 255]
#    (3006, 0040)  Contour Sequence   1 item(s) ----
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: "1"
#       (3006, 0050) Contour Data                        DS: [-36.182096, -249.365627, -687.836645]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: "43"
#    ---------
#    (3006, 002a) ROI Display Color                   IS: [0, 0, 255]
#    (3006, 0040)  Contour Sequence   1 item(s) ----
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: "1"
#       (3006, 0050) Contour Data                        DS: [-23.681647, -226.707888, -689.286581]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: "44"
#    ---------
#    (3006, 002a) ROI Display Color                   IS: [0, 0, 255]
#    (3006, 0040)  Contour Sequence   1 item(s) ----
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: "1"
#       (3006, 0050) Contour Data                        DS: [-61.093444, -243.442810, -696.825000]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: "45"
#    ---------
#    (3006, 002a) ROI Display Color                   IS: [0, 0, 255]
#    (3006, 0040)  Contour Sequence   1 item(s) ----
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: "1"
#       (3006, 0050) Contour Data                        DS: [-60.214844, -236.464844, -718.208724]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: "46"
#    ---------
#    (3006, 002a) ROI Display Color                   IS: [0, 0, 255]
#    (3006, 0040)  Contour Sequence   1 item(s) ----
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: "1"
#       (3006, 0050) Contour Data                        DS: [-63.594966, -239.095585, -718.202908]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: "47"
#    ---------
#    (3006, 002a) ROI Display Color                   IS: [0, 0, 255]
#    (3006, 0040)  Contour Sequence   1 item(s) ----
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: "1"
#       (3006, 0050) Contour Data                        DS: [-52.714844, -217.769644, -713.265804]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: "48"
#    ---------
#    (3006, 002a) ROI Display Color                   IS: [0, 0, 255]
#    (3006, 0040)  Contour Sequence   1 item(s) ----
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: "1"
#       (3006, 0050) Contour Data                        DS: [-33.829840, -208.454898, -693.597146]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: "49"
#    ---------
#    (3006, 002a) ROI Display Color                   IS: [0, 0, 255]
#    (3006, 0040)  Contour Sequence   1 item(s) ----
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: "1"
#       (3006, 0050) Contour Data                        DS: [-46.714844, -229.714844, -674.691276]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: "50"
#    ---------
#    (3006, 002a) ROI Display Color                   IS: [0, 0, 255]
#    (3006, 0040)  Contour Sequence   1 item(s) ----
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: "1"
#       (3006, 0050) Contour Data                        DS: [-72.753616, -232.614015, -709.575000]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: "51"
#    ---------
#    (3006, 002a) ROI Display Color                   IS: [0, 0, 255]
#    (3006, 0040)  Contour Sequence   1 item(s) ----
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: "1"
#       (3006, 0050) Contour Data                        DS: [-45.964844, -242.387916, -711.075000]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: "52"
#    ---------
#    (3006, 002a) ROI Display Color                   IS: [0, 0, 255]
#    (3006, 0040)  Contour Sequence   1 item(s) ----
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: "1"
#       (3006, 0050) Contour Data                        DS: [-40.503402, -242.008179, -697.819569]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: "53"
#    ---------
#    (3006, 002a) ROI Display Color                   IS: [0, 0, 255]
#    (3006, 0040)  Contour Sequence   1 item(s) ----
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: "1"
#       (3006, 0050) Contour Data                        DS: [-31.850750, -218.464844, -714.825000]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: "54"
#    ---------
#    (3006, 002a) ROI Display Color                   IS: [0, 0, 255]
#    (3006, 0040)  Contour Sequence   1 item(s) ----
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: "1"
#       (3006, 0050) Contour Data                        DS: [-66.964844, -233.464844, -718.208724]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: "55"
#    ---------
#    (3006, 002a) ROI Display Color                   IS: [0, 0, 255]
#    (3006, 0040)  Contour Sequence   1 item(s) ----
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: "1"
#       (3006, 0050) Contour Data                        DS: [-29.781796, -230.225544, -701.325000]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: "56"
#    ---------
#    (3006, 002a) ROI Display Color                   IS: [0, 0, 255]
#    (3006, 0040)  Contour Sequence   1 item(s) ----
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: "1"
#       (3006, 0050) Contour Data                        DS: [-75.224015, -230.458382, -690.067056]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: "57"
#    ---------
#    (3006, 002a) ROI Display Color                   IS: [0, 0, 255]
#    (3006, 0040)  Contour Sequence   1 item(s) ----
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: "1"
#       (3006, 0050) Contour Data                        DS: [-22.919187, -237.964844, -681.995335]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: "58"
#    ---------
#    (3006, 002a) ROI Display Color                   IS: [0, 0, 255]
#    (3006, 0040)  Contour Sequence   1 item(s) ----
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: "1"
#       (3006, 0050) Contour Data                        DS: [-72.536523, -241.714844, -676.144631]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: "59"
#    ---------
#    (3006, 002a) ROI Display Color                   IS: [0, 0, 255]
#    (3006, 0040)  Contour Sequence   1 item(s) ----
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: "1"
#       (3006, 0050) Contour Data                        DS: [-42.214844, -212.731851, -709.289395]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: "60"
#    ---------
#    (3006, 002a) ROI Display Color                   IS: [0, 0, 255]
#    (3006, 0040)  Contour Sequence   1 item(s) ----
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: "1"
#       (3006, 0050) Contour Data                        DS: [-24.549132, -233.602042, -680.665883]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: "61"
#    ---------
#    (3006, 002a) ROI Display Color                   IS: [0, 0, 255]
#    (3006, 0040)  Contour Sequence   1 item(s) ----
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: "1"
#       (3006, 0050) Contour Data                        DS: [-69.499175, -231.794319, -677.325000]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: "62"
#    ---------
#    (3006, 002a) ROI Display Color                   IS: [0, 0, 255]
#    (3006, 0040)  Contour Sequence   1 item(s) ----
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: "1"
#       (3006, 0050) Contour Data                        DS: [-39.964844, -260.464844, -674.691276]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: "63"
#    ---------
#    (3006, 002a) ROI Display Color                   IS: [0, 0, 255]
#    (3006, 0040)  Contour Sequence   1 item(s) ----
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: "1"
#       (3006, 0050) Contour Data                        DS: [-44.272428, -243.503223, -698.579907]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: "64"
#    ---------
#    (3006, 002a) ROI Display Color                   IS: [0, 0, 255]
#    (3006, 0040)  Contour Sequence   1 item(s) ----
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: "1"
#       (3006, 0050) Contour Data                        DS: [-69.613269, -236.867184, -691.575000]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: "65"
#    ---------
#    (3006, 002a) ROI Display Color                   IS: [0, 0, 255]
#    (3006, 0040)  Contour Sequence   1 item(s) ----
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: "1"
#       (3006, 0050) Contour Data                        DS: [-77.153285, -228.149032, -687.137832]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: "66"
#    ---------
#    (3006, 002a) ROI Display Color                   IS: [0, 0, 255]
#    (3006, 0040)  Contour Sequence   1 item(s) ----
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: "1"
#       (3006, 0050) Contour Data                        DS: [-59.446518, -257.467749, -677.896630]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: "67"
#    ---------
#    (3006, 002a) ROI Display Color                   IS: [0, 0, 255]
#    (3006, 0040)  Contour Sequence   1 item(s) ----
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: "1"
#       (3006, 0050) Contour Data                        DS: [-61.714844, -213.684259, -708.391850]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: "68"
#    ---------
#    (3006, 002a) ROI Display Color                   IS: [0, 0, 255]
#    (3006, 0040)  Contour Sequence   1 item(s) ----
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: "1"
#       (3006, 0050) Contour Data                        DS: [-33.991899, -248.329048, -687.846225]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: "69"
#    ---------
#    (3006, 002a) ROI Display Color                   IS: [0, 0, 255]
#    (3006, 0040)  Contour Sequence   1 item(s) ----
#       (3006, 0042) Contour Geometric Type              CS: 'POINT'
#       (3006, 0046) Number of Contour Points            IS: "1"
#       (3006, 0050) Contour Data                        DS: [-47.832071, -242.093026, -718.202908]
#       ---------
#    (3006, 0084) Referenced ROI Number               IS: "70"
#    ---------
# (300c, 0002)  Referenced RT Plan Sequence   1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: RT Plan Storage
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.3.6.1.4.1.2452.6.1305624465.1085343903.354807171.2727083074
#    ---------
# (7fe0, 0010) Pixel Data                          OW: Array of 3369336 elements

# %%
braquiarray=ds.pixel_array

print("Nuestra imágen se puede representar con una matriz de dimensión: " + str(braquiarray.shape) + " Y el tipo de datos de cada pixel es: " + str(braquiarray[0,0,0].dtype) + " Y una resolución de " + str(ds.PixelSpacing) + " mm")
# Out:
# Nuestra imágen se puede representar con una matriz de dimensión: (103, 94, 87) Y el tipo de datos de cada pixel es: uint32 Y una resolución de [1.000000, 1.000000] mm

# %%
ds.DoseGridScaling
# Out:
# "1.303852e-08"

# %%
# El objetivo es igualar sólo en tamaño la imágen de dosis a la de tomografía, las dos son de la misma sesión de braquiterapia
# Como las imágenes de tomografía se encuentran sueltas adapatamos un código para poder visualiar nuestra tomografía
# y poder visualizar a qué dimensiones queremos llegar.

# %%
import os
import glob

# %%
# Cargo la carpeta donde guardé las imágenes de tomografía de interés.
# Aegurarse de hacer los mismos pasos que en el código anterior, pero ésta vez, ingresar sólo la ruta de la carpeta de 
# nuestros archivos.

INPUT_FOLDER = (str(input('Ingrese la ruta de la carpeta de archivos: ')))
patients =  os.listdir(INPUT_FOLDER)
patients.sort()
# Out:
# Ingrese la ruta de la carpeta de archivos: D:\Users\user\Documents\Tesis Ana\tomografía

# %%
lstFilesDCM = []   # creo una lista vacía y voy agreagando los archivos DICOM en la lista
def load_scan2(path):
    for dirName, subdirList, fileList in os.walk(path):
        for filename in fileList:
            if ".dcm" in filename.lower():  
                lstFilesDCM.append(os.path.join(dirName, filename))
    return lstFilesDCM

first_patient = load_scan2(INPUT_FOLDER)
print(lstFilesDCM)  #para visualizar la lista
# Out:
# ['D:\\Users\\user\\Documents\\Tesis Ana\\tomografía\\CT.1.3.6.1.4.1.2452.6.1050360180.1080925630.4052450701.2777985367.dcm', 'D:\\Users\\user\\Documents\\Tesis Ana\\tomografía\\CT.1.3.6.1.4.1.2452.6.1050832576.1256051437.2329617317.1496777816.dcm', 'D:\\Users\\user\\Documents\\Tesis Ana\\tomografía\\CT.1.3.6.1.4.1.2452.6.1099158148.1152470789.649348487.2294417522.dcm', 'D:\\Users\\user\\Documents\\Tesis Ana\\tomografía\\CT.1.3.6.1.4.1.2452.6.1103699967.1202030004.3538137739.218986907.dcm', 'D:\\Users\\user\\Documents\\Tesis Ana\\tomografía\\CT.1.3.6.1.4.1.2452.6.1123829523.1166706541.1582403474.2390353480.dcm', 'D:\\Users\\user\\Documents\\Tesis Ana\\tomografía\\CT.1.3.6.1.4.1.2452.6.1128137084.1095995010.2735128224.1396351511.dcm', 'D:\\Users\\user\\Documents\\Tesis Ana\\tomografía\\CT.1.3.6.1.4.1.2452.6.1179475750.1302181624.1499302333.1627008488.dcm', 'D:\\Users\\user\\Documents\\Tesis Ana\\tomografía\\CT.1.3.6.1.4.1.2452.6.1215710027.1218615975.1353761943.1718505500.dcm', 'D:\\Users\\user\\Documents\\Tesis Ana\\tomografía\\CT.1.3.6.1.4.1.2452.6.1254499787.1335798210.3354315433.2882231531.dcm', 'D:\\Users\\user\\Documents\\Tesis Ana\\tomografía\\CT.1.3.6.1.4.1.2452.6.128558733.1327509590.4049013917.258810246.dcm', 'D:\\Users\\user\\Documents\\Tesis Ana\\tomografía\\CT.1.3.6.1.4.1.2452.6.1315667054.1119381924.1282829480.824822760.dcm', 'D:\\Users\\user\\Documents\\Tesis Ana\\tomografía\\CT.1.3.6.1.4.1.2452.6.1326531678.1293265236.716436396.2904848006.dcm', 'D:\\Users\\user\\Documents\\Tesis Ana\\tomografía\\CT.1.3.6.1.4.1.2452.6.1355628862.1110433659.926619279.3197418171.dcm', 'D:\\Users\\user\\Documents\\Tesis Ana\\tomografía\\CT.1.3.6.1.4.1.2452.6.1355689463.1167163278.1682893481.3850296193.dcm', 'D:\\Users\\user\\Documents\\Tesis Ana\\tomografía\\CT.1.3.6.1.4.1.2452.6.1379782095.1095875384.816981695.3458614919.dcm', 'D:\\Users\\user\\Documents\\Tesis Ana\\tomografía\\CT.1.3.6.1.4.1.2452.6.1425175693.1160838753.2523160492.2403233132.dcm', 'D:\\Users\\user\\Documents\\Tesis Ana\\tomografía\\CT.1.3.6.1.4.1.2452.6.1449720574.1178009145.875894967.2465743266.dcm', 'D:\\Users\\user\\Documents\\Tesis Ana\\tomografía\\CT.1.3.6.1.4.1.2452.6.1526925226.1213499035.2410591365.846487726.dcm', 'D:\\Users\\user\\Documents\\Tesis Ana\\tomografía\\CT.1.3.6.1.4.1.2452.6.1545485759.1098790748.4107414410.945300179.dcm', 'D:\\Users\\user\\Documents\\Tesis Ana\\tomografía\\CT.1.3.6.1.4.1.2452.6.1617065395.1141288665.4292888464.2514208954.dcm', 'D:\\Users\\user\\Documents\\Tesis Ana\\tomografía\\CT.1.3.6.1.4.1.2452.6.1655242.1306796179.1311035826.4020766558.dcm', 'D:\\Users\\user\\Documents\\Tesis Ana\\tomografía\\CT.1.3.6.1.4.1.2452.6.1666374741.1164623069.4116515985.1549619672.dcm', 'D:\\Users\\user\\Documents\\Tesis Ana\\tomografía\\CT.1.3.6.1.4.1.2452.6.1697434958.1224098103.1965856438.92631098.dcm', 'D:\\Users\\user\\Documents\\Tesis Ana\\tomografía\\CT.1.3.6.1.4.1.2452.6.1703762175.1205974203.1287719349.3749527921.dcm', 'D:\\Users\\user\\Documents\\Tesis Ana\\tomografía\\CT.1.3.6.1.4.1.2452.6.1750670742.1278631362.1273822123.4083251239.dcm', 'D:\\Users\\user\\Documents\\Tesis Ana\\tomografía\\CT.1.3.6.1.4.1.2452.6.1764956910.1238257084.208888741.2832903393.dcm', 'D:\\Users\\user\\Documents\\Tesis Ana\\tomografía\\CT.1.3.6.1.4.1.2452.6.1765712942.1320224311.2925708211.1050040096.dcm', 'D:\\Users\\user\\Documents\\Tesis Ana\\tomografía\\CT.1.3.6.1.4.1.2452.6.1799731268.1335072983.2318090682.3402733149.dcm', 'D:\\Users\\user\\Documents\\Tesis Ana\\tomografía\\CT.1.3.6.1.4.1.2452.6.1867292878.1265366067.590666896.420494968.dcm', 'D:\\Users\\user\\Documents\\Tesis Ana\\tomografía\\CT.1.3.6.1.4.1.2452.6.1884152389.1094738355.2280172967.1883785068.dcm', 'D:\\Users\\user\\Documents\\Tesis Ana\\tomografía\\CT.1.3.6.1.4.1.2452.6.1905200543.1254539044.2859932337.2677664991.dcm', 'D:\\Users\\user\\Documents\\Tesis Ana\\tomografía\\CT.1.3.6.1.4.1.2452.6.1931537502.1170418472.1610059675.1440405947.dcm', 'D:\\Users\\user\\Documents\\Tesis Ana\\tomografía ...

# %%
print (lstFilesDCM[0]) #visualizo el primer elemento de la lista

RefDs = pydicom.read_file(lstFilesDCM[0]) #leo el primer elemento

# Cargo las dimensiones basadas en el numnero de filas, columnas,y cortes(a lo largo del eje z)
ConstPixelDims = (int(RefDs.Rows), int(RefDs.Columns), len(lstFilesDCM))

# Cargo el espácio entre los datos (en mm)
ConstPixelSpacing = (float(RefDs.PixelSpacing[0]), float(RefDs.PixelSpacing[1]), float(RefDs.SliceThickness))


x = np.arange(0.0, (ConstPixelDims[0]+1)*ConstPixelSpacing[0], ConstPixelSpacing[0])
y = np.arange(0.0, (ConstPixelDims[1]+1)*ConstPixelSpacing[1], ConstPixelSpacing[1])
z = np.arange(0.0, (ConstPixelDims[2]+1)*ConstPixelSpacing[2], ConstPixelSpacing[2])
# Out:
# D:\Users\user\Documents\Tesis Ana\tomografía\CT.1.3.6.1.4.1.2452.6.1050360180.1080925630.4052450701.2777985367.dcm

# %%
# El arreglo está dimensionado en 'ConstPixelDims'
cortes=[]
ArrayDicom = np.zeros(ConstPixelDims, dtype=RefDs.pixel_array.dtype)

# Bucle a través de todos los archivos DICOM
for filenameDCM in lstFilesDCM:
    # Leo el archivo
    ds_ct = pydicom.read_file(filenameDCM)
    cortes.append(ds_ct[0x020, 0x032].value[2])
    # Almaceno los datos de imágen sin procesar
    ArrayDicom[:, :, lstFilesDCM.index(filenameDCM)] = ds_ct.pixel_array

# %%
# de todos los cortes, sacamos aquel que tiene el máximo en su coordenada (número de corte en mm)
min(cortes)
# Out:
# "-848.7"

# %%
print("Nuestra tomografía se representa con una matriz de dimensión " + str(ArrayDicom.shape) + " Y cada píxel es de tipo " + str(ArrayDicom[0,0,0].dtype) + " Con una resolución de " + str(RefDs.PixelSpacing) + " mm")
# Out:
# Nuestra tomografía se representa con una matriz de dimensión (512, 512, 144) Y cada píxel es de tipo uint16 Con una resolución de [0.8203125, 0.8203125] mm

# %%
# Nuestra fórmula para redimensionar sería: DimBraqui=DimRadioMax / PixelSpacingRadio
DimBraqui=braquiarray.shape
DimRadio=ArrayDicom.shape
ResTC=RefDs.PixelSpacing[0]

# %%
DimRadio
# Out:
# (512, 512, 144)

# %%
DimBraqui
# Out:
# (103, 94, 87)

# %%
ceros=np.zeros([int(DimRadio[2]*RefDs.SliceThickness),int(DimRadio[0]*ResTC),int(DimRadio[1]*ResTC)])

# %%
ceros.shape
# Out:
# (216, 420, 420)

# %%
# Transformamos el tipo de datos para igualarlo con la imágen de braqui
ceros.dtype
# Out:
# dtype('float64')

# %%
cerosdosis=ceros.astype(braquiarray.dtype)

# %%
#rtdose
rtdose=ds[0x020, 0x032].value
rtdose
# Out:
# [-95.250000, -276.731000, -747.057000]

# %%
#tc
tc=RefDs[0x020, 0x032].value
tc
# Out:
# [-249.58984375, -441.58984375, -821.7]

# %%
#numero de frames
inicio0=abs(ds[0x020, 0x032].value[2]+braquiarray.shape[0])-abs(int(min(cortes))+(ArrayDicom.shape[2]*RefDs.SliceThickness))
inicio0
# Out:
# 12.057000000000016

# %%
inicio0=(cerosdosis.shape[0])-inicio0-braquiarray.shape[0]
inicio0
# Out:
# 100.94299999999998

# %%
#filas
#inicio1= abs(ds[0x020, 0x032].value[1]+braquiarray.shape[1])-abs(RefDs[0x020, 0x032].value[1]+ArrayDicom.shape[0]) 
inicio1=abs(ds[0x020, 0x032].value[1])-abs(RefDs[0x020, 0x032].value[1])
inicio1
# Out:
# -164.85884375

# %%
#columnas
inicio2= abs(ds[0x020, 0x032].value[0])-abs(RefDs[0x020, 0x032].value[0]) 
inicio2
# Out:
# -154.33984375

# %%
# Realizamos el zeropadding

contador=np.arange(braquiarray.shape[0])

for i in contador:
    cualquiera=braquiarray[i]
    cerosdosis[int(abs(inicio0))+i , int(abs(inicio1)):abs(int(abs(inicio1))+cualquiera.shape[0]) , int(abs(inicio2)):abs(int(abs(inicio2))+cualquiera.shape[1])]=cualquiera

# %%
#Visualizamos un corte para corroborar que se hizo el zeropadding como queríamos

plt.imshow(cerosdosis[:,194,:])
plt.show()

# %%
# Procesdemos a guardar nuestra nueva imágen

ds.PixelData=cerosdosis.tobytes('C')
ds.Rows,ds.Columns =cerosdosis[0].shape
ds[0x28, 0x08].value=cerosdosis.shape[0]

# %%
plt.imshow(ds.pixel_array[:,190,::])
plt.show()

# %%
# Esta parte del codigo es para no sobreescribir las distintas imágenes que vamos modificando
# Acordarse de incluir la extensión '.dcm'

ds.save_as(str(input('Ingrese nombre del archivo')))
# Out:
# Ingrese nombre del archivo'nuevo_braqui_pt1.dcm'

# %%
#out_path = "D:/Users/user/Documents/Tesis Ana/Nuevas dosis"
#os.path.join(out_path, image)
